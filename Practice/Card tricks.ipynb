# %%
import random

suits = ['Hearts', 'Diamonds', 'Clubs', 'Spades']
ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']

card =random.choice(suit)
# Out:
# Pick a number between 1 and 52 to pick your card (simulating the magic choice):
#
# 🔮 Magical reveal... Your card is: 4 of Hearts
