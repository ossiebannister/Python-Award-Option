# %%
score = int(input("enter your score (100-0)"))
if score >=70:
    print("That is a A score")
elif score >=60:
 print("That is a B score")
elif score >=50:
 print("That is a C score")
elif score >=40:
 print("that is a D score")
else:
    print("Grade F")
# Out:
# That is a A score

# %%
password = input("Enter your password")
if len(password) >= 8 and "secure" in password:
    print("Valid password")
else:
 print("Invalid password")
# Out:
# Valid password

# %%
import random

rolls = int(input("how many times do you want to roll the dice?"))

for i in range(rolls):
    dice 1 = random.randint (1,6)
    dice 2 = random.randint (1,6)
    total = dice 1 + dice 2 

    print(roll dice answers)
# Out:
#   Cell In[14], line 6
#     dice 1 = random.randint (1,6)
#          ^
# SyntaxError: invalid syntax
