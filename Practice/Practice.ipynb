# %%
name = input("Enter your name")
age = int(input("How old are you"))
colour = input("What is your favourite colour")

print(f"Hi, I'm {name}, I'm {age} and my favourite colour is {colour}.")
# Out:
# Hi, I'm Ossie, I'm 16 and my favourite colour is blue.

# %%
num1 = float(input("Enter your first number: "))
num2 = float(input("Enter your second number: "))

sum_result = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print(f"sum: {sum_result}")
print(f"difference: {difference}")
print(f"product: {product}")
print(f"quotient: {quotient}")
# Out:
# sum: 3782.0
# difference: -3692.0
# product: 168165.0
# quotient: 0.012041744715012041

# %%
def celcius_to_fahrenheit(celcius):
    fahrenheit = (celcius * 9/5) + 32
    return fahrenheit

temp1 = celcius_to_fahrenheit(0)
temp2 = celcius_to_fahrenheit(25)
temp3 = celcius_to_fahrenheit(100)

print(f"0 = {temp1}")
print(f"25 = {temp2}")
print(f"100 = {temp3}")
# Out:
# 0 = 32.0
# 25 = 77.0
# 100 = 212.0
