# %%
subjects = []
for i in range(6):
    subject = input(f"Enter a subject {i+1}: ")
    topic = input(f'Enter the topic for {subject}: ')
    subjects.append((subject,topic))
print(subjects)
# Out:
# [('history ', 'ww2'), ('geog', 'global migration'), ('maths', 'trig'), ('chem', 'bonds'), ('phy', 'moments'), ('comp science', 'programming')]

# %%
subs = [('history ', 'ww2'), ('geog', 'global migration'), ('maths', 'trig'), ('chem', 'bonds'), ('phy', 'moments'), ('comp science', 'programming')]
for i in range(len(subs)):
    print(f'{subs[i][0]}\t{subs[i][1]}')
# Out:
# history 	ww2
# geog	global migration
# maths	trig
# chem	bonds
# phy	moments
# comp science	programming
